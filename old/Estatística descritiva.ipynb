# %%
# Inicialmente, importar a dependências necessárias

import pandas as pd # --> Ler e importar dados de planilhas para um dataframe
from google.colab import files # --> importar arquivos no colab
import io # --> ajudar na manipulação de arquivos

# %% [markdown]
# # Exercício prático de Projeto Integrador V-A
# Aluno: Vinícius Guimarães Muniz
# ### Objetivo:
# Demonstrar o carregamento de uma planilha no Pandas e fazer a média de alguns
# valores para fins de demonstração.

# %%
# Faz upload do arquivo
data_source = files.upload()
# Out:
#      <input type="file" id="files-0df59f38-3b68-40ec-a2b9-c567829671d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0df59f38-3b68-40ec-a2b9-c567829671d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving some_data.xlsx to some_data.xlsx

# %%
# Lê o arquivo da planilha e coloca seu conteúdo em um dataframe
df = pd.read_excel(io.BytesIO(data_source['some_data.xlsx']))

# %%
# Aqui visualizamos o dataframe
df
# Out:
#     Cód Imóvel           Locador           Locatário  \
# 0            1      Juliana Lima     Gustavo Andrade
# 1            2    Pedro Henrique       Adriano Rocha
# 2            3    Carlos Eduardo    Bruno Figueiredo
# 3            4         Ana Clara       Dayane Santos
# 4            5      José Augusto       Natália Alves
# 5            6  Guilherme Santos  Alice Pazini Rimar
# 6            7     Alex Medeiros         João Miguel
# 7            8       Paulo Silva        Enzo Gabriel
# 8            9   João dos Santos       Maria Cecilia
# 9           10      Myllena Rosa       Maria Eduarda
# 10          11     Whallef Rimar         Maria Alice
# 11          12   Graciane Pazini          João Lucas
# 12          13  Gildásio Pereira           Ana Julia
# 13          14      Marcos Paulo         Maria Clara
# 14          15       Pedro Silva          João Pedro
# 15          16      Luana Santos         Maria Luiza
# 16          17     Alisson Souza    Álvaro Gutierrez
# ...

# %%
# Análise dos valores de algumas colunas do dataframe, especificadas entre chaves abaixo
df[{'Cód Imóvel','Aluguel','Juros (%)','Dia Vcto'}].describe(include='all')
# Out:
#        Cód Imóvel   Dia Vcto  Juros (%)       Aluguel
# count   19.000000  19.000000  19.000000     19.000000
# mean    10.000000  17.947368   0.081053   3162.105263
# std      5.627314   8.771632   0.034624   2888.085350
# min      1.000000   1.000000   0.030000    830.000000
# 25%      5.500000  12.500000   0.055000   1112.500000
# 50%     10.000000  20.000000   0.070000   2150.000000
# 75%     14.500000  25.000000   0.100000   3500.000000
# max     19.000000  30.000000   0.150000  10200.000000
